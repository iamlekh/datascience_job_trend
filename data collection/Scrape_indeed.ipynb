# %%
from selenium import webdriver
import pandas as pd 
from bs4 import BeautifulSoup
import time

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('C:\\Users\\kiit\\Documents\\machine learning\\web_scraping\\chromedriver.exe')
df = pd.DataFrame(columns=["Title","Location","Company","Salary","Sponsored","Description"])

for i in range(160,200,10):
	driver.get('https://www.indeed.co.in/jobs?q=artificial+intelligence&l=India&start='+str(i))
	jobs = []
	driver.implicitly_wait(4)
	time.sleep(2)

	for job in driver.find_elements_by_class_name('result'):
        
		soup = BeautifulSoup(job.get_attribute('innerHTML'),'html.parser')
		#time.sleep(1)
		try:
			title = soup.find("a",class_="jobtitle").text.replace("\n","").strip()
			
		except:
			title = 'None'

		try:
			location = soup.find(class_="location").text
		except:
			location = 'None'

		try:
			company = soup.find(class_="company").text.replace("\n","").strip()
		except:
			company = 'None'

		try:
			salary = soup.find(class_="salary").text.replace("\n","").strip()
		except:
			salary = 'None'

		try:
			sponsored = soup.find(class_="sponsoredGray").text
			sponsored = "Sponsored"
		except:
			sponsored = "Organic"				

		
		sum_div = job.find_element_by_xpath('./div[3]')
		try:
			sum_div.click()
		except:
			close_button = driver.find_elements_by_class_name('popover-x-button-close')[0]
			close_button.click()
			sum_div.click()	
		job_desc = driver.find_element_by_id('vjs-desc').text

		df = df.append({'Title':title,'Location':location,"Company":company,"Salary":salary,
						"Sponsored":sponsored,"Description":job_desc},ignore_index=True)

		print("Got these many results:",df.shape,company)


df.to_csv("INDEED_glassdoor_ai6.csv",index=False)	
print("done")
# Out:
# Got these many results: (1, 6) Whitehat Education Technology Pvt. Ltd.
# Got these many results: (2, 6) Whitehat Education Technology Pvt. Ltd.
# Got these many results: (3, 6) Whitehat Education Technology Pvt. Ltd.
# Got these many results: (4, 6) Saveetha Engineering College
# Got these many results: (5, 6) Careerera
# Got these many results: (6, 6) Panjab University
# Got these many results: (7, 6) Predii
# Got these many results: (8, 6) SYSTOOLS SOFTWARE
# Got these many results: (9, 6) Embold Technologies GmbH
# Got these many results: (10, 6) Mindtree
# Got these many results: (11, 6) Silicus Technologies
# Got these many results: (12, 6) PRATHAM Education
# Got these many results: (13, 6) NVIDIA
# Got these many results: (14, 6) PatientMD
# Got these many results: (15, 6) Whitehat Education Technology Pvt. Ltd.
# Got these many results: (16, 6) Whitehat Education Technology Pvt. Ltd.
# Got these many results: (17, 6) Whitehat Education Technology Pvt. Ltd.
# ...
