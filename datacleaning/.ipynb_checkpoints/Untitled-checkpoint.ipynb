# %%
import pandas as pd

# %%
dfai = pd.read_csv("/media/kiit/9B8F-064E/project/ds_salary/data collection/glassdoor_artificial-intelligence-engineer300.csv")
dfml = pd.read_csv("/media/kiit/9B8F-064E/project/ds_salary/data collection/glassdoor_machine-learning-engineer1000.csv")
dfds = pd.read_csv("/media/kiit/9B8F-064E/project/ds_salary/data collection/glassdoor_data_scientist1000.csv")

# %%
#concate
frames = [dfds, dfml, dfai]
df = pd.concat(frames)
df.shape
# Out:
# (2300, 14)

# %%
df = df.drop_duplicates(subset=['Job Description', 'Job Title'], keep='first')
df.shape
# Out:
# (1602, 14)

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership'],
#       dtype='object')

# %%
#drop columns
df.drop(['Competitors','Revenue','Salary Estimate'], inplace = True, axis  = 1)

# %%
#parse comp[any name]
df['Company Name'] = df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
#headquater
def country(x):
    a = x.split(',')
    try:
        if a[1] is not None:
            return a[1]
        elif a[0] == '-1':
            return "unknown"
        else:
            return a[0]
    except:
        return "unknown" if a[0]== '-1' else a[0]
df['Headquarters'] = df['Headquarters'].apply(country)

# %%
#ratings
df['Rating'] = df['Rating'].apply(lambda x: 0 if x == -1.0 else x)

# %%
#sector
df['Sector'] = df['Sector'].apply(lambda x: 'unknown' if x == '-1' else x)

# %%
#size
df['Size'] = df['Size'].apply(lambda x: 'unknown' if x == '-1' else x)

# %%
#Type of ownership
df['Type of ownership'] = df['Type of ownership'].apply(lambda x: 'unknown' if x == '-1' else x)

# %%
df['Job Description'].fillna("unknown", inplace = True)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#r in job describtion
df['r_studio']= df['Job Description'].astype(str).apply(lambda x: 1 if 'r studio' or 'r-studio' in x.lower() else 0)

# %%
#SQL in job describtion
df['SQL']= df['Job Description'].astype(str).apply(lambda x: 1 if 'sql' in x.lower() else 0)

# %%
#SAS in job describtion
df['SAS']= df['Job Description'].astype(str).apply(lambda x: 1 if 'sas' in x.lower() else 0)

# %%
#spark in job describtion
df['spark']= df['Job Description'].astype(str).apply(lambda x: 1 if 'spark' in x.lower() else 0)

# %%
#aws in job describtion
df['aws']= df['Job Description'].astype(str).apply(lambda x: 1 if 'aws'or 'amazon'  in x.lower() else 0)

# %%
#google clous in job describtion
df['Google_cloud']= df['Job Description'].astype(str).apply(lambda x: 1 if 'google cloud' in x.lower() else 0)

# %%
#azure in job describtion
df['azure']= df['Job Description'].astype(str).apply(lambda x: 1 if 'azure' in x.lower() else 0)

# %%
#bigdata in job describtion
df['big data']= df['Job Description'].astype(str).apply(lambda x: 1 if 'hadoop' or 'hive' or 'pig' in x.lower() else 0)

# %%
#qlik in job describtion
df['qlik']= df['Job Description'].astype(str).apply(lambda x: 1 if 'qlik' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
#python in job describtion
df['python']= df['Job Description'].astype(str).apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
df.sort_values('Company Name')
# Out:
#                          Company Name  Founded Headquarters  \
# 853               159 Solutions, Inc.     2017           NC
# 269              3D-IP Semiconductors       -1        India
# 252                            6sense     2013           CA
# 352                            6sense     2013           CA
# 334                            6sense     2013           CA
# 372                            6sense     2013           CA
# 755                           99Games       -1        India
# 773       ACUWIN INNOVATIONS Pvt Ltd.       -1      unknown
# 143       ACUWIN INNOVATIONS Pvt Ltd.       -1      unknown
# 720                 ADCI - BLR 14 SEZ       -1      unknown
# 843                 ADCI - BLR 14 SEZ       -1      unknown
# 849                    ADCI - Haryana       -1      unknown
# 142                  ADCI - Karnataka       -1      unknown
# 865                  ADCI - Karnataka       -1      unknown
# 375                  ADCI - Karnataka       -1      unknown
# 715                  ADCI - Karnataka       -1      unknown
# 621                  ADCI - Karnataka       -1      unknown
# 888                  ADCI - Karnataka       -1      unknown
# 627                  ADCI - Karnataka       -1      unknown
# 595                  ADCI - Karnataka       -1      unknown
# 668                  ADCI - Karnataka       -1      unknown
# 467                ADCI - Maharashtra       -1           TX
# 449                 ADCI - Tamil Nadu       -1      unknown
# 429                   ADCI HYD 13 SEZ       -1      unknown
# 852                   ADCI HYD 13 SEZ       -1      unknown
# 465                   ADCI HYD 13 SEZ       -1      unknown
# 227                   ADCI HYD 13 SEZ       -1      unknown
# 597                   ADCI HYD 13 SEZ       -1      unknown
# 873                 ADSIN - Karnataka       -1      unknown
# 235                          AGUILASS       -1      unknown
# ..                                ...      ...          ...
# 541  iNVERTEDi IT Consultancy Pvt Ltd     2011        India
# 816    iScientific TechSolutions Labs       -1      unknown
# 860                 innData Analytics     2015        India
# 45                         inteliment       -1        India
# 642                           iqm.com     2014           NY
# 94                            iqm.com     2014           NY
# 454                           itForte       -1        India
# 128                           itForte       -1        India
# 825       jobsinchennaiarea@gmail.com       -1      unknown
# 692          kyte Tech Consulting LLP     2015        India
# 893           lemark institute of art       -1        India
# 92              loyalytics consulting     2015        India
# 187             loyalytics consulting     2015        India
# 704                newAmps Consulting     2015        India
# 300                o9 Solutions, Inc.     2009           TX
# 735                             sRide     2015        India
# 774                      smart4talent     2009        India
# 873                         tarantula     1997    Singapore
# 874                         tarantula       -1        India
# 189              torcai digital media       -1      unknown
# 622  upGrad Education Private Limited     2015        India
# 491  upGrad Education Private Limited     2015        India
# 354  upGrad Education Private Limited     2015        India
# 357  upGrad Education Private Limited     2015        India
# 565  upGrad Education Private Limited     2015        India
# 800                           vPhrase     2015        India
# 551                        wayForward       -1           NY
# 388                        wayForward       -1           NY
# 440               zBliss Technologies       -1      unknown
# 279                             zyoin     2005        India
#
#                                     Industry  \
# 853                Biotech & Pharmaceuticals
# 269                                       -1
# 252             Computer Hardware & Software
# 352             Computer Hardware & Software
# 334             Computer Hardware & Software
# 372             Computer Hardware & Software
# 755             Computer Hardware & Software
# 773                                       -1
# 143                                       -1
# 720                                       -1
# 843                                       -1
# 849                                       -1
# 142                                       -1
# 865                                       -1
# 375                                       -1
# 715                                       -1
# 621                                       -1
# 888                                       -1
# 627                                       -1
# 595                                       -1
# 668                                       -1
# 467                                       -1
# 449                                       -1
# 429                                       -1
# 852                                       -1
# 465                                       -1
# 227                                       -1
# 597                                       -1
# 873                                       -1
# 235                                       -1
# ..                                       ...
# 541                                       -1
# 816                                       -1
# 860             Computer Hardware & Software
# 45                               IT Services
# 642                                 Internet
# 94                                  Internet
# 454                                       -1
# 128                                       -1
# 825                                       -1
# 692  Enterprise Software & Network Solutions
# 893                                       -1
# 92                               IT Services
# 187                              IT Services
# 704                              IT Services
# 300  Enterprise Software & Network Solutions
# 735                Transportation Management
# 774                   Staffing & Outsourcing
# 873                              IT Services
# 874                   Staffing & Outsourcing
# 189                                       -1
# 622              Education Training Services
# 491              Education Training Services
# 354              Education Training Services
# 357              Education Training Services
# 565              Education Training Services
# 800  Enterprise Software & Network Solutions
# 551                                       -1
# 388                                       -1
# 440                                       -1
# 279                   Staffing & Outsourcing
#
#                                        Job Description  \
# 853  Analytical consultants will have the opportuni...
# 269  Position\nWe are hiring senior data scientist ...
# 252  Description\n\n6sense is a Predictive Intellig...
# 352  Revenue Operations Data Analyst\n\nJob Descrip...
# 334  Responsibilities:\nWe are looking to add a Dat...
# 372  Description\n\n\n6sense is a Predictive Intell...
# 755  99Games is looking for a Data Analyst to help ...
# 773  We are looking for a passionate machine learni...
# 143  We are looking for a experienced Data scientis...
# 720  PhD/Master Degree in Computer Science with exp...
# 843  Bachelor’s Degree in Computer Science or relat...
# 849  Bachelor or Master in computer science\nSolid ...
# 142  2+ years of non-internship professional softwa...
# 865  Bachelor’s degree in Computer Science or relat...
# 375  Pursuing Masters or equivalent advanced degree...
# 715  Bachelor’s or Master’s degree in a quantitativ...
# 621  Bachelor's degree and/or Master's degree in Co...
# 888  A MS or PhD in Computer Science or Machine lea...
# 627  Basic Qualifications:\nVery good English skill...
# 595  6+ years of practical experience applying ML t...
# 668  3+ years of experience as a Data Engineer or i...
# 467  0-2 years of non-internship professional softw...
# 449  2+ years of non-internship professional softwa...
# 429  MS or PhD in Data Science, Mathematics, Statis...
# 852  Development experience in one or more object-o...
# 465  3+ years of experience as a Data Engineer or i...
# 227  Bachelor's or Master’s degree in Statistics, A...
# 597  3+ years of experience as an analyst or engine...
# 873  BS in Computer Science or related technical fi...
# 235  3- 6 Years – Hyderabad, Gurgaon\nJob Descripti...
# ..                                                 ...
# 541  Experience\n1-3 years of application developme...
# 816  Designation:\nData Analyst\n\nExperience:\n0 -...
# 860  Location : Visakhapatnam\n\nExperience : 5-6 y...
# 45   JOB DESCRIPTION\n\nData Scientist\n\nRole : Da...
# 642  Min. Exp: 1 year\nAhmedabad, India\nJob Role\n...
# 94   Min. Exp: 3 years\nAhmedabad, India\nJob Role\...
# 454  Founded in 1987 and listed on NASDAQ, our clie...
# 128  Our client is seeking a creative Data Scientis...
# 825  Job Responsibilities:\n\nDear Candidates,\n\nA...
# 692  Position Summary:\nThe Data Analyst is respons...
# 893  As a Data Scientist, Geospatial you will work ...
# 92   Experience required: 2-4 years\n\nWe are looki...
# 187  Job Title: Data Scientist\nExperience required...
# 704  Stipend As per the industry standard\nLocation...
# 300  Analytics/Data Scientist\n\n\nWe at o9 Solutio...
# 735  What are we looking for:\nProblem Solving & An...
# 774  Designation : Data Analyst\nQualification: BA ...
# 873  Interpret data and turn it into information th...
# 874  The Formulary Data Analyst is responsible for ...
# 189  Roles and Responsibilities\nUnderstand clients...
# 622  About Us\n\nupGrad is an online education plat...
# 491  About Us\n\nupGrad is an online education plat...
# 354  About Us\n\nupGrad is an online education plat...
# 357  About Us\n\nupGrad is an online education plat...
# 565  About Us\n\nupGrad is an online education plat...
# 800  Lead Data Scientist\n\n31st January 2020\n\nBy...
# 551  wayForward (aka PsyInnovations Inc) was establ...
# 388  wayForward (aka PsyInnovations Inc) was establ...
# 440  Internship Cohort Team Size : 3\n\nApply only ...
# 279  We are looking for a “Data Scientist” for one ...
#
#                                              Job Title            Location  \
# 853                               Analytics Consultant                Pune
# 269                              Senior Data Scientist           Bengaluru
# 252                Senior Frontend Engineer (React.js)                Pune
# 352                    Revenue Operations Data Analyst                Pune
# 334                                Senior Data Analyst                Pune
# 372                                Full Stack Engineer           Bengaluru
# 755                                       Data Analyst               Udupi
# 773                          Machine Learning Engineer  Thiruvananthapuram
# 143                                     Data Scientist  Thiruvananthapuram
# 720                               Applied Scientist II           Bengaluru
# 843                      Software Development Engineer           Bengaluru
# 849                      Software Development Engineer             Gurgaon
# 142        Software Engineer, Machine Learning Systems           Bengaluru
# 865                                      Data Engineer           Bengaluru
# 375                              Data Scientist Intern           Bengaluru
# 715                              Senior Data Scientist           Bengaluru
# 621                      Software Development Engineer           Bengaluru
# 888                              Applied Scientist III           Bengaluru
# 627                                Applied Scientist I           Bengaluru
# 595                                  Applied Scientist           Bengaluru
# 668                                      Data Engineer           Bengaluru
# 467                      Software Development Engineer              Mumbai
# 449  Software Development Engineer, Amazon Machine ...             Chennai
# 429                                  Data Scientist II           Hyderabad
# 852                     System Development Engineer II           Hyderabad
# 465                                      Data Engineer           Hyderabad
# 227                                     Data Scientist           Hyderabad
# 597                  Business Intelligence Engineer II           Hyderabad
# 873                      Software Development Engineer           Bengaluru
# 235                                     Data Scientist           Hyderabad
# ..                                                 ...                 ...
# 541                               Analytics Consultant               India
# 816                                       Data Analyst           Hyderabad
# 860      Sr. Big Data Engineer - Cloudera/ Hortonworks       Visakhapatnam
# 45                                      Data Scientist                Pune
# 642                                      Data Engineer           Ahmedabad
# 94                                      Data Scientist           Ahmedabad
# 454                             Data Analyst/Scientist             Gurgaon
# 128                                     Data Scientist             Gurgaon
# 825                                       Data Analyst          Tamil Nadu
# 692                                       Data Analyst           Ahmedabad
# 893                                       Data Science              Mumbai
# 92                                      Data Scientist           Bengaluru
# 187                                     Data Scientist           Bengaluru
# 704                                Data Science Intern             Kolkata
# 300               Analytical consultant/Data Scientist           Bengaluru
# 735                                Senior Data Analyst               India
# 774                                       Data Analyst              Mumbai
# 873                                       Data Analyst           Hyderabad
# 874                   Formulary Data Analyst (Trainee)           Bengaluru
# 189                                     Data Scientist                Pune
# 622                               Senior Data Engineer              Mumbai
# 491                                Senior Data Analyst              Mumbai
# 354                    Senior Software Engineer (Java)           Bengaluru
# 357       SDET (Software Development Engineer in Test)           Bengaluru
# 565                Senior Software Engineer (Frontend)              Mumbai
# 800                                Lead Data Scientist                Pune
# 551              Senior Software Engineer (Full Stack)           New Delhi
# 388            Senior Software Engineer in Test (SSET)           New Delhi
# 440                              Data Scientist Intern           Bengaluru
# 279  Data Scientist (4+ Years) for an Online Ecomme...           Bengaluru
#
#      Rating                      Sector                   Size  \
# 853     3.6   Biotech & Pharmaceuticals       10000+ employees
# 269     4.0                     unknown                Unknown
# 252     4.9      Information Technology    51 to 200 employees
# 352     4.9      Information Technology    51 to 200 employees
# 334     4.9      Information Technology    51 to 200 employees
# 372     4.9      Information Technology    51 to 200 employees
# 755     3.8      Information Technology    51 to 200 employees
# 773     0.0                     unknown                unknown
# 143     0.0                     unknown                unknown
# 720     0.0                     unknown                unknown
# 843     0.0                     unknown                unknown
# 849     0.0                     unknown                unknown
# 142     0.0                     unknown                unknown
# 865     0.0                     unknown                unknown
# 375     0.0                     unknown                unknown
# 715     0.0                     unknown                unknown
# 621     0.0                     unknown                unknown
# 888     0.0                     unknown                unknown
# 627     0.0                     unknown                unknown
# 595     0.0                     unknown                unknown
# 668     0.0                     unknown                unknown
# 467     0.0                     unknown                Unknown
# 449     0.0                     unknown                unknown
# 429     0.0                     unknown                unknown
# 852     0.0                     unknown                unknown
# 465     0.0                     unknown                unknown
# 227     0.0                     unknown                unknown
# 597     0.0                     unknown                unknown
# 873     0.0                     unknown                unknown
# 235     0.0                     unknown                unknown
# ..      ...                         ...                    ...
# 541     3.5                     unknown      1 to 50 employees
# 816     0.0                     unknown                unknown
# 860     4.5      Information Technology      1 to 50 employees
# 45      4.0      Information Technology    51 to 200 employees
# 642     0.0      Information Technology      1 to 50 employees
# 94      0.0      Information Technology      1 to 50 employees
# 454     5.0                     unknown      1 to 50 employees
# 128     5.0                     unknown      1 to 50 employees
# 825     0.0                     unknown                unknown
# 692     3.3      Information Technology    51 to 200 employees
# 893     0.0                     unknown                Unknown
# 92      5.0      Information Technology      1 to 50 employees
# 187     5.0      Information Technology      1 to 50 employees
# 704     3.7      Information Technology      1 to 50 employees
# 300     3.3      Information Technology   201 to 500 employees
# 735     4.9  Transportation & Logistics      1 to 50 employees
# 774     0.0           Business Services      1 to 50 employees
# 873     3.3      Information Technology    51 to 200 employees
# 874     2.0           Business Services      1 to 50 employees
# 189     0.0                     unknown                unknown
# 622     4.0                   Education  501 to 1000 employees
# 491     4.0                   Education  501 to 1000 employees
# 354     4.0                   Education  501 to 1000 employees
# 357     4.0                   Education  501 to 1000 employees
# 565     4.0                   Education  501 to 1000 employees
# 800     4.4      Information Technology      1 to 50 employees
# 551     3.5                     unknown      1 to 50 employees
# 388     3.5                     unknown      1 to 50 employees
# 440     0.0                     unknown                unknown
# 279     3.7           Business Services    51 to 200 employees
#
#      Type of ownership  python
# 853   Company - Public       0
# 269  Company - Private       1
# 252  Company - Private       1
# 352  Company - Private       0
# 334  Company - Private       0
# 372  Company - Private       1
# 755  Company - Private       0
# 773            unknown       1
# 143            unknown       1
# 720            unknown       1
# 843            unknown       0
# 849            unknown       0
# 142            unknown       1
# 865            unknown       1
# 375            unknown       1
# 715            unknown       1
# 621            unknown       0
# 888            unknown       1
# 627            unknown       1
# 595            unknown       0
# 668            unknown       1
# 467  Company - Private       0
# 449            unknown       1
# 429            unknown       1
# 852            unknown       0
# 465            unknown       1
# 227            unknown       1
# 597            unknown       1
# 873            unknown       1
# 235            unknown       0
# ..                 ...     ...
# 541  Company - Private       0
# 816            unknown       0
# 860  Company - Private       1
# 45   Company - Private       1
# 642  Company - Private       1
# 94   Company - Private       1
# 454  Company - Private       0
# 128  Company - Private       1
# 825            unknown       1
# 692  Company - Private       0
# 893  Company - Private       1
# 92   Company - Private       1
# 187  Company - Private       1
# 704  Company - Private       1
# 300  Company - Private       1
# 735            Unknown       0
# 774  Company - Private       0
# 873  Company - Private       0
# 874  Company - Private       0
# 189            unknown       0
# 622  Company - Private       1
# 491  Company - Private       1
# 354  Company - Private       0
# 357  Company - Private       0
# 565  Company - Private       0
# 800  Company - Private       1
# 551  Company - Private       0
# 388  Company - Private       0
# 440            unknown       1
# 279  Company - Private       1
#
# [1602 rows x 12 columns]

# %%
l = ['.net','full stack','java' ,'qa','quality','app','ios','nodejs','embedded','infrastructure' ,'design','mobile',
 'customer', 'care', 'backend', 'hardware', 'design', 'automation', 'bios', 'front-end', 'performance','test', 'data operations', 'oracle', 'productivity', 'cyber', 'security', 'qa', 'android', 'website', 'staff', 'api', 'test', 'full stack', 'app', 'frontend', 'localisation']
for i in range(len(l)):
    print(l[i],df['Job Title'].astype(str).apply(lambda x: 1 if l[i] in x.lower() else 0).value_counts())
# Out:
# .net 0    2293
# 1       7
# Name: Job Title, dtype: int64
# full stack 0    2282
# 1      18
# Name: Job Title, dtype: int64
# java 0    2262
# 1      38
# Name: Job Title, dtype: int64
# qa 0    2280
# 1      20
# Name: Job Title, dtype: int64
# quality 0    2288
# 1      12
# Name: Job Title, dtype: int64
# app 0    2216
# 1      84
# Name: Job Title, dtype: int64
# ios 0    2295
# 1       5
# Name: Job Title, dtype: int64
# nodejs 0    2299
# 1       1
# Name: Job Title, dtype: int64
# embedded 0    2288
# 1      12
# Name: Job Title, dtype: int64
# infrastructure 0    2281
# 1      19
# Name: Job Title, dtype: int64
# design 0    2286
# 1      14
# Name: Job Title, dtype: int64
# mobile 0    2292
# 1       8
# Name: Job Title, dtype: int64
# customer 0    2288
# 1      12
# Name: Job Title, dtype: int64
# care 0    2296
# 1       4
# Name: Job Title, dtype: int64
# backend 0    2294
# 1       6
# Name: Job Title, dtype: int64
# hardware 0    2289
# 1      11
# Name: Job Title, dtype: int64
# design 0    2286
# 1      14
# Name: Job Title, dtype: int64
# automation 0    2274
# 1      26
# Name: Job Title, dtype: int64
# bios 0    2298
# 1       2
# Name: Job Title, dtype: int64
# front-end 0    2298
# 1       2
# Name: Job Title, dtype: int64
# performance 0    2297
# 1       3
# Name: Job Title, dtype: int64
# test 0    2280
# 1      20
# Name: Job Title, dtype: int64
# data operations 0    2299
# 1       1
# Name: Job Title, dtype: int64
# oracle 0    2296
# 1       4
# Name: Job Title, dtype: int64
# productivity 0    2299
# 1       1
# Name: Job Title, dtype: int64
# cyber 0    2297
# 1       3
# Name: Job Title, dtype: int64
# security 0    2287
# 1      13
# Name: Job Title, dtype: int64
# qa 0    2280
# 1      20
# Name: Job Title, dtype: int64
# android 0    2291
# 1       9
# Name: Job Title, dtype: int64
# website 0    2299
# 1       1
# Name: Job Title, dtype: int64
# staff 0    2277
# 1      23
# Name: Job Title, dtype: int64
# api 0    2290
# 1      10
# Name: Job Title, dtype: int64
# test 0    2280
# 1      20
# Name: Job Title, dtype: int64
# full stack 0    2282
# 1      18
# Name: Job Title, dtype: int64
# app 0    2216
# 1      84
# Name: Job Title, dtype: int64
# frontend 0    2291
# 1       9
# Name: Job Title, dtype: int64
# localisation 0    2299
# 1       1
# Name: Job Title, dtype: int64

# %%
#remove other job title

# %%
for i in range(len(l)):
    df[~df['Job Title'].str.contains(l[i])]

# %%
df['Job Title'] = df['Job Title'].apply(lambda x: x.lower())

# %%
df.shape
# Out:
# (1602, 12)

# %%
df = df[~df['Job Title'].isin(l)]
